# %%
# %run convert_to_vector.ipynb
# Out:
# C:\Users\khanh\AppData\Local\Temp\ipykernel_20500\655128731.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Tiêu đề'][i] = list(news_dataset['Nội dung'][i].split('.'))[0]
# C:\Users\khanh\AppData\Local\Temp\ipykernel_20500\2103798904.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Tiêu đề'][i] = text_preprocess(news_dataset['Tiêu đề'][i])
# C:\Users\khanh\AppData\Local\Temp\ipykernel_20500\2103798904.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#huấn luyện sử dụng Logistic Regression
from sklearn.linear_model import LogisticRegression
  
model = LogisticRegression()
model.fit(x_train, y_train)
  
accuracy_score(y_train, model.predict(x_train)), accuracy_score(y_test, model.predict(x_test))
# Out:
# (0.8258426966292135, 0.7752808988764045)

# %%
#huấn luyện sử dụng Decision Tree
from sklearn.tree import DecisionTreeClassifier
  
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
  
accuracy_score(y_train, model.predict(x_train)), accuracy_score(y_test, model.predict(x_test))
# Out:
# (1.0, 0.8876404494382022)

# %%
#ma trận nhầm lẫn của cây quyết định
from sklearn import metrics
import matplotlib.pyplot as plt
cm = metrics.confusion_matrix(y_test, model.predict(x_test))
  
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=cm,
                                            display_labels=[False, True])
  
cm_display.plot()
plt.show()

# %%
#do cây quyết định có tỉ lệ dự đoán đúng cao hơn nên ta sẽ sử dụng cây quyết định để dự đoán
for i in range(x_test.shape[0]):
    prediction = model.predict(x_test[i])
    if(prediction[0] == 0):
        print('Tin thứ {} là tin tức giả'.format(i + 1))
    else:
        print('Tin thứ {} là tin tức thật'.format(i + 1))
# Out:
# Tin thứ 1 là tin tức thật
# Tin thứ 2 là tin tức giả
# Tin thứ 3 là tin tức giả
# Tin thứ 4 là tin tức thật
# Tin thứ 5 là tin tức thật
# Tin thứ 6 là tin tức thật
# Tin thứ 7 là tin tức thật
# Tin thứ 8 là tin tức thật
# Tin thứ 9 là tin tức thật
# Tin thứ 10 là tin tức giả
# Tin thứ 11 là tin tức thật
# Tin thứ 12 là tin tức giả
# Tin thứ 13 là tin tức thật
# Tin thứ 14 là tin tức thật
# Tin thứ 15 là tin tức giả
# Tin thứ 16 là tin tức thật
# Tin thứ 17 là tin tức thật
# Tin thứ 18 là tin tức thật
# Tin thứ 19 là tin tức thật
# Tin thứ 20 là tin tức thật
# Tin thứ 21 là tin tức giả
# Tin thứ 22 là tin tức giả
# Tin thứ 23 là tin tức giả
# Tin thứ 24 là tin tức thật
# Tin thứ 25 là tin tức thật
# Tin thứ 26 là tin tức thật
# Tin thứ 27 là tin tức thật
# Tin thứ 28 là tin tức thật
# Tin thứ 29 là tin tức thật
# Tin thứ 30 là tin tức thật
# Tin thứ 31 là tin tức thật
# Tin thứ 32 là tin tức thật
# Tin thứ 33 là tin tức thật
# Tin thứ 34 là tin tức thật
# Tin thứ 35 là tin tức thật
# ...

# %%
# Ghi ra dự đoán
prediction_dataset = pd.read_excel('test.xlsx')
prediction_dataset['Dự đoán'] = pd.Series(index=prediction_dataset.index)
prediction_dataset['Kết quả'] = pd.Series(index=prediction_dataset.index)

for i in range(x_test.shape[0]):
    prediction = model.predict(x_test[i])
    prediction_dataset['Dự đoán'][i] = int(prediction[0])
    if (prediction[0] == prediction_dataset['Nhãn'][i]):
        prediction_dataset['Kết quả'][i] = 'Đúng'
    else:
        prediction_dataset['Kết quả'][i] = 'Sai'
prediction_dataset.to_excel('predict.xlsx', index=False)
# Out:
# C:\Users\khanh\AppData\Local\Temp\ipykernel_20500\236759974.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   prediction_dataset['Dự đoán'] = pd.Series(index=prediction_dataset.index)
# C:\Users\khanh\AppData\Local\Temp\ipykernel_20500\236759974.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   prediction_dataset['Kết quả'] = pd.Series(index=prediction_dataset.index)
# C:\Users\khanh\AppData\Local\Temp\ipykernel_20500\236759974.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prediction_dataset['Dự đoán'][i] = int(prediction[0])
# ...
