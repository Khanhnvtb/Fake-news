# %%
# %run convert_to_vector.ipynb
# Out:
# C:\Users\khanh\AppData\Local\Temp\ipykernel_5540\655128731.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Tiêu đề'][i] = list(news_dataset['Nội dung'][i].split('.'))[0]
# C:\Users\khanh\AppData\Local\Temp\ipykernel_5540\2265512805.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Tiêu đề'][i] = text_preprocess(news_dataset['Tiêu đề'][i])
# C:\Users\khanh\AppData\Local\Temp\ipykernel_5540\2265512805.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Tác giả'][i] = text_preprocess(news_dataset['Tác giả'][i])
# C:\Users\khanh\AppData\Local\Temp\ipykernel_5540\2265512805.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Nội dung'][i] = text_preprocess(news_dataset['Nội dung'][i])
# [('của', 396), ('là', 320), ('và', 294), ('có', 270), ('người', 263), ('đã', 240), ('không', 234), ('được', 231), ('cho', 218), ('ở', 207), ('một', 203), ('trong', 202), ('các', 182), ('với', 177), ('khi', 171), ('năm', 160), ('để', 159), ('sau', 147), ('về', 142), ('nhiều', 132), ('này', 131), ('những', 121), ('việt_nam', 120), ('tại', 117), ('bị', 112), ('vào', 112), ('ông', 111), ('lại', 110), ('đi', 109), ('đến', 109), ('nhà', 107), ('từ', 107), ('anh', 103), ('ra', 103), ('cũng', 103), ('1', 101), ('cô', 100), ('bạn', 99), ('sẽ', 98), ('trên', 98), ('nhưng', 98), ('2', 95), ('vì', 92), ('ngày', 92), ('thì', 92), ('10', 92), ('mà', 92), ('hơn', 84), ('đó', 82), ('làm', 80), ('theanh28', 79), ('theo', 78), ('còn', 77), ('chỉ', 76), ('tuổi', 76), ('tiền', 73), ('trước', 72), ('mới', 72), ('con', 70), ('biết', 70), ('triệu', 69), ('như', 69), ('phải', 68), ('đang', 67), ('nước', 63), ('2022', 62), ('hai', 62), ('dân', 61), ('lao_động', 61), ('đồng', 60), ('tp', 59), ('mình', 59), ('nhất', 59), ('em', 58), ('hà_nội', 57), ('nói', 56), ('lên', 56), ('việc', 56), ('3', 56), ('đảng', 55), ('cả', 55), ('vẫn', 53), ('cùng', 53), ('sự', 52), ('có_thể', 51), ('tới', 50), ('lần', 50), ('nên', 50), ('lúc', 48), ('tháng', 48), ('đây', 48), ('gần', 47), ('qua', 47), ('khiến', 45), ('xã_hội', 44), ('đưa', 44), ('gái', 44), ('cao', 44), ('rất', 44), ('5', 43), ('số', 43), ('bằng', 43), ('trung_quốc', 42), ('hcm', 41), ('học', 41), ('rằng', 41), ('chưa', 40), ('bên', 40), ('lớn', 40), ('thế_giới', 39), ('hàng', 39), ('t', 39), ('cưới', 38), ('tỷ', 38), ('tân_cao', 38), ('thêm', 36), ('lương', 36), ('thấy', 35), ('thứ', 35), ('trai', 35), ('bộ', 35), ('bà', 34), ('tăng', 33), ('đường', 33), ('rồi', 33), ('trường', 32), ('sao', 32), ('đóng', 32), ('do', 32), ('thời_gian', 32), ('tôi', 31), ('chồng', 31), ('tổ_chức', 31), ('công_nhân', 31), ('mỹ', 31), ('huyện', 31), ('gì', 31), ('nhận', 31), ('20', 30), ('đài_loan', 30), ('chủ', 30), ('gặp', 30), ('vợ', 30), ('viết_tuân', 30), ('trọng', 29), ('mỗi', 29), ('cái', 29), ('cần', 29), ('sáng', 29), ('họ', 29), ('chị', 29), ('đội', 28), ('hết', 28), ('mạng', 28), ('bộ_trưởng', 28), ('ngoài', 28), ('gây', 28), ('vừa', 28), ('tối', 28), ('n', 28), ('từng', 27), ('sống', 27), ('mất', 27), ('đất', 27), ('muốn', 27), ('tỉnh', 27), ('4', 27), ('cách', 27), ('hay', 27), ('mẹ', 26), ('khó', 26), ('nguyễn', 26), ('chuyện', 26), ('lấy', 25), ('nam', 25), ('tin', 25), ('giảm', 25), ('nay', 25), ('chia_sẻ', 25), ('điều', 25), ('đều', 25), ('quận', 24), ('thu_nhập', 24), ('mang', 24), ('hoa_hậu', 24), ('lãnh_đạo', 24), ('nhau', 24), ('ngay', 24), ('lê_tuyết', 24), ('khoảng', 23), ('diễn_viên', 23), ('7', 23), ('12', 23), ('cuộc', 23), ('quốc_gia', 23), ('việt_tân', 23), ('khác', 23), ('phát_triển', 23), ('world_cup', 22), ('ăn', 22), ('y_tế', 22), ('ai', 22), ('một_số', 22), ('đêm', 22), ('vụ', 22), ('mua', 22), ('xe', 22), ('chàng', 22), ('gia_đình', 22), ('quốc_hội', 22), ('ca_sĩ', 22), ('m', 22), ('mức', 22), ('quyết_định', 22), ('nếu', 22), ('mới_đây', 22), ('như_anh', 22), ('trận', 21), ('không_thể', 21), ('sang', 21), ('diễn', 21), ('xem', 21), ('facebook', 21), ('công_ty', 21), ('đầu', 21), ('thế', 21), ('lời', 21), ('công_an', 21), ('tập', 21), ('thi', 20), ('cháu', 20), ('luôn', 20), ('nhà_nước', 20), ('6', 20), ('kinh_tế', 20), ('quản_lý', 20), ('nơi', 20), ('chiều', 20), ('nào', 20), ('chân', 20), ('hồng_chiêu', 20), ('chính_phủ', 20), ('việt', 19), ('giờ', 19), ('bệnh_viện', 19), ('v', 19), ('dù', 19), ('tặng', 19), ('sân', 19), ('hành_vi', 19), ('cơ_quan', 19), ('tất_cả', 19), ('giúp', 19), ('rừng', 19), ('thành_phố', 19), ('đ', 19), ('báo', 18), ('̉', 18), ('quá', 18), ('phần', 18), ('bỏ', 18), ('khu_vực', 18), ('bởi', 18), ('đề_nghị', 18), ('khỏi', 18), ('nữ', 18), ('30', 18), ('xăng', 18), ('miss', 18), ('xảy', 18), ('tên', 18), ('mọi', 18), ('9', 18), ('đối_với', 18), ('chính', 18), ('phát_hiện', 17), ('tay', 17), ('giữ', 17), ('2023', 17), ('nghỉ', 17), ('11', 17), ('sinh', 17), ('nhóm', 17),  ...
# C:\Users\khanh\AppData\Local\Temp\ipykernel_5540\308898851.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Tiêu đề'][i] = remove_stopwords(news_dataset['Tiêu đề'][i])
# C:\Users\khanh\AppData\Local\Temp\ipykernel_5540\308898851.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Tác giả'][i] = remove_stopwords(news_dataset['Tác giả'][i])
# C:\Users\khanh\AppData\Local\Temp\ipykernel_5540\308898851.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_dataset['Nội dung'][i] = remove_stopwords(news_dataset['Nội dung'][i])

# %%
#huấn luyện sử dụng Logistic Regression
from sklearn.linear_model import LogisticRegression
  
model = LogisticRegression()
model.fit(x_train, y_train)
  
accuracy_score(y_train, model.predict(x_train)), accuracy_score(y_test, model.predict(x_test))
# Out:
# (0.8314606741573034, 0.6853932584269663)

# %%
#huấn luyện sử dụng Decision Tree
from sklearn.tree import DecisionTreeClassifier
  
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
  
accuracy_score(y_train, model.predict(x_train)), accuracy_score(y_test, model.predict(x_test))
# Out:
# (1.0, 0.898876404494382)

# %%
#ma trận nhầm lẫn của cây quyết định
from sklearn import metrics
import matplotlib.pyplot as plt
cm = metrics.confusion_matrix(y_test, model.predict(x_test))
  
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=cm,
                                            display_labels=[False, True])
  
cm_display.plot()
plt.show()

# %%
#do cây quyết định có tỉ lệ dự đoán đúng cao hơn nên ta sẽ sử dụng cây quyết định để dự đoán
for i in range(x_test.shape[0]):
    prediction = model.predict(x_test[i])
    if(prediction[0] == 0):
        print('Tin thứ {} là tin tức giả'.format(i + 1))
    else:
        print('Tin thứ {} là tin tức thật'.format(i + 1))
# Out:
# Tin thứ 1 là tin tức thật
# Tin thứ 2 là tin tức giả
# Tin thứ 3 là tin tức thật
# Tin thứ 4 là tin tức thật
# Tin thứ 5 là tin tức thật
# Tin thứ 6 là tin tức thật
# Tin thứ 7 là tin tức thật
# Tin thứ 8 là tin tức giả
# Tin thứ 9 là tin tức giả
# Tin thứ 10 là tin tức thật
# Tin thứ 11 là tin tức giả
# Tin thứ 12 là tin tức giả
# Tin thứ 13 là tin tức thật
# Tin thứ 14 là tin tức thật
# Tin thứ 15 là tin tức giả
# Tin thứ 16 là tin tức thật
# Tin thứ 17 là tin tức giả
# Tin thứ 18 là tin tức thật
# Tin thứ 19 là tin tức giả
# Tin thứ 20 là tin tức thật
# Tin thứ 21 là tin tức thật
# Tin thứ 22 là tin tức thật
# Tin thứ 23 là tin tức thật
# Tin thứ 24 là tin tức thật
# Tin thứ 25 là tin tức giả
# Tin thứ 26 là tin tức thật
# Tin thứ 27 là tin tức giả
# Tin thứ 28 là tin tức thật
# Tin thứ 29 là tin tức thật
# Tin thứ 30 là tin tức thật
# Tin thứ 31 là tin tức thật
# Tin thứ 32 là tin tức thật
# Tin thứ 33 là tin tức giả
# Tin thứ 34 là tin tức thật
# Tin thứ 35 là tin tức giả
# Tin thứ 36 là tin tức giả
# Tin thứ 37 là tin tức giả
# Tin thứ 38 là tin tức thật
# Tin thứ 39 là tin tức thật
# Tin thứ 40 là tin tức thật
# Tin thứ 41 là tin tức thật
# Tin thứ 42 là tin tức thật
# Tin thứ 43 là tin tức thật
# Tin thứ 44 là tin tức thật
# Tin thứ 45 là tin tức thật
# Tin thứ 46 là tin tức thật
# Tin thứ 47 là tin tức thật
# Tin thứ 48 là tin tức giả
# Tin thứ 49 là tin tức thật
# Tin thứ 50 là tin tức thật
# Tin thứ 51 là tin tức giả
# Tin thứ 52 là tin tức giả
# Tin thứ 53 là tin tức thật
# Tin thứ 54 là tin tức thật
# Tin thứ 55 là tin tức thật
# Tin thứ 56 là tin tức thật
# Tin thứ 57 là tin tức giả
# Tin thứ 58 là tin tức giả
# Tin thứ 59 là tin tức thật
# Tin thứ 60 là tin tức thật
# Tin thứ 61 là tin tức thật
# Tin thứ 62 là tin tức thật
# Tin thứ 63 là tin tức thật
# Tin thứ 64 là tin tức giả
# Tin thứ 65 là tin tức thật
# Tin thứ 66 là tin tức thật
# Tin thứ 67 là tin tức thật
# Tin thứ 68 là tin tức thật
# Tin thứ 69 là tin tức thật
# Tin thứ 70 là tin tức thật
# Tin thứ 71 là tin tức thật
# Tin thứ 72 là tin tức giả
# Tin thứ 73 là tin tức giả
# Tin thứ 74 là tin tức thật
# Tin thứ 75 là tin tức thật
# Tin thứ 76 là tin tức giả
# Tin thứ 77 là tin tức giả
# Tin thứ 78 là tin tức thật
# Tin thứ 79 là tin tức thật
# Tin thứ 80 là tin tức giả
# Tin thứ 81 là tin tức thật
# Tin thứ 82 là tin tức thật
# Tin thứ 83 là tin tức thật
# Tin thứ 84 là tin tức thật
# Tin thứ 85 là tin tức thật
# Tin thứ 86 là tin tức thật
# Tin thứ 87 là tin tức thật
# Tin thứ 88 là tin tức thật
# Tin thứ 89 là tin tức thật
